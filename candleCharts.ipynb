# %%
print("Python with R for Stock Data Analysis")
# Out:
# Python with R for Stock Data Analysis

# %%
# !pip3 install jupyter_http_over_ws

# %%
# !jupyter serverextension enable — py jupyter_http_over_ws
# Out:
# Enabling: —
# - Writing config: /root/.jupyter
#     - Validating...
# Error loading server extension —
#       X is — importable?
# Enabling: py
# - Writing config: /root/.jupyter
#     - Validating...
#       X is py importable?
# Enabling: jupyter_http_over_ws
# - Writing config: /root/.jupyter
#     - Validating...
# Error loading server extension jupyter_http_over_ws
#       X is jupyter_http_over_ws importable?

# %%
# !pip3 install rpy2

# %%
# %reload_ext rpy2.ipython

# %%
import pandas as pd
pdf = pd.read_csv("ABL PA Equity.csv")
pdf.head()
# Out:
#          Date    Open    High     Low   Close   Volume
# 0  2005-08-17  1.4809  7.2563  5.1831  6.2789  38266.0
# 1  2005-08-18  1.4809  7.2563  5.1831  6.2789  38266.0
# 2  2005-08-19  6.2789  6.2938  6.1086  6.2789  16582.0
# 3  2005-08-22  6.2789  6.4418  6.2567  6.3678  73980.0
# 4  2005-08-23  6.3678  6.3678  6.0494  6.3086  42092.0

# %%
# %R -i pdf

# %%
# %%R
#
# sapply(pdf, function(x) sum(is.infinite (x)))
# Out:
#   Date   Open   High    Low  Close Volume
#      0      0      0      0      0      0

# %%
# %%R
# install.packages("timetk")
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/timetk_2.6.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 3793775 bytes (3.6 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# #converting data frame into time series data
# library(timetk)
# rdf <- xts::xts(pdf[,c('Open','High','Low','Close','Volume')], order.by = as.Date(pdf$Date))
# head(rdf)
# Out:
#              Open   High    Low  Close Volume
# 2005-08-17 1.4809 7.2563 5.1831 6.2789  38266
# 2005-08-18 1.4809 7.2563 5.1831 6.2789  38266
# 2005-08-19 6.2789 6.2938 6.1086 6.2789  16582
# 2005-08-22 6.2789 6.4418 6.2567 6.3678  73980
# 2005-08-23 6.3678 6.3678 6.0494 6.3086  42092
# 2005-08-24 6.3086 6.3604 6.1457 6.1605  33164

# %%
# %%R
# install.packages("xts")
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/xts_0.12.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 517875 bytes (505 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# library(xts)

# %%
# %%R
# rdf <- xts(pdf[,c('Open','High','Low','Close','Volume')], order.by = as.Date(pdf$Date))
# head(rdf)
# Out:
#              Open   High    Low  Close Volume
# 2005-08-17 1.4809 7.2563 5.1831 6.2789  38266
# 2005-08-18 1.4809 7.2563 5.1831 6.2789  38266
# 2005-08-19 6.2789 6.2938 6.1086 6.2789  16582
# 2005-08-22 6.2789 6.4418 6.2567 6.3678  73980
# 2005-08-23 6.3678 6.3678 6.0494 6.3086  42092
# 2005-08-24 6.3086 6.3604 6.1457 6.1605  33164

# %%
# %%R
# plot(rdf[100:150,"Close"], main = "ABOT")

# %%
# %%R
#
# install.packages("quantmod")
# library(quantmod)
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/quantmod_0.4.18.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 154512 bytes (150 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
#
# candleChart(rdf[100:150], up.col = "green", dn.col = "red", theme="white")

# %%
# %%R
#
# addSMA(n=c(10,26))

# %%
# %%R
#
# addRSI()

# %%
# %%R
#
# addMACD()

# %%
# %%R
#
# addBBands()
