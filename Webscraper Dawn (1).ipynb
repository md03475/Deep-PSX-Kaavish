# %%
import requests

# %%
pip install ipython-beautifulsoup
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import bs4

from urllib.request import urlopen as uReq

# %%
from bs4 import BeautifulSoup as soup

# %%
my_url = 'https://www.dawn.com/archive/2020-08-12/'

# %%
uClient = uReq(my_url)  #load url
page_html = uClient.read() #set page into vairable.
uClient.close()

# %%
page_soup = soup(page_html, 'html.parser')  #html parser

# %%
page_soup.h1
# Out:
# <h1 class="text-hide logo mx-auto mb-2">
#                     DAWN.COM
#                 </h1>

# %%
articles = page_soup.findAll('div',{'class':'flex'})

# %%
len(articles)
# Out:
# 6

# %%
print(articles[3])
# Out:
# <div class="flex no-gutters">
# <div class="flex__item w-11/12">
# <!-- - - - article - - - -->
# <article class="box story border-b border-b-grey-default border-b-solid pb-2 mb-4" data-id="1574044" data-layout="story">
# <!-- box/label -->
# <span class="badge inline-flex text-3 theme theme--sport align-middle" dir="auto"><a class="text-3" href="/sport" title="Sport">Sport</a></span>
# <!-- box/title  -->
# <h2 class="story__title" data-id="1574044" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1574044/hafeez-to-self-isolate-after-breaching-bio-security-protocol-in-england">Hafeez to self-isolate after breaching bio-security protocol in England
# </a></h2>
# <!-- box/excerpt -->
# <div class="story__excerpt" dir="auto">The all-rounder breached the two-metre social distancing protocol by posing for a photo with a member of the public.
# ...

# %%
result = requests.get('https://www.dawn.com/archive/2020-08-12/')

# %%
# Out:
# {'Date': 'Sat, 07 Nov 2020 09:29:02 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dcfd1b16b933037ccdf90e7dc734add151604741340; expires=Mon, 07-Dec-20 09:29:00 GMT; path=/; domain=.dawn.com; HttpOnly; SameSite=Lax', 'X-Developer': 'Enjoy webdev? We like you, reach out at topcoder(at)compunode.com', 'X-Backend': 'nk3', 'Vary': 'Accept-Encoding, x-ua-device', 'X-G': 'none', 'CF-Cache-Status': 'DYNAMIC', 'cf-request-id': '0643a2b69800001d7b57af5000000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report?s=cfhz2ewlHA4UW6bRtdw1BVn6GZc0GbCglSAaH4dyLJp2WGX%2Bu3PA7kxtAxwcZnO%2BVJsQFtkn%2Bb7QWWXdXUc9YCQF0RGwk59Vv6eDOOw%3D"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"report_to":"cf-nel","max_age":604800}', 'Server': 'cloudflare', 'CF-RAY': '5ee607042a3f1d7b-NRT', 'Content
# ...

# %%
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>  <html lang="en" class="ie ie6 lte9 lte8 lte7"> <![endif]-->\n<!--[if IE 7]>     <html lang="en" class="ie ie7 lte9 lte8 lte7"> <![endif]-->\n<!--[if IE 8]>     <html lang="en" class="ie ie8 lte9 lte8"> <![endif]-->\n<!--[if IE 9]>     <html lang="en" class="ie ie9 lte9"> <![endif]-->\n<!--[if gt IE 9]>  <html lang="en"> <![endif]-->\n<!--[if !IE]><!--> <html lang="en"> <!--<![endif]-->\n<head>\n  \n    <!-- meta -->\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">\n    <!--[if IE]> <meta http-equiv="X-UA-Compatible" content="IE=edge" /> <![endif]-->\n    <title>News Archives for 2020-08-12 - DAWN.COM</title> \n     <meta name=\'subject\' content=\'Your window to latest news, analysis and features from Pakistan, South Asia and the world.\' />  \n     <meta property=\'fb:app_id\' content=\'1383068068604634\' /> \n     <meta property=\'fb:pages\' content=\'86398345441\' /> \n     <m
# ...

# %%
# Out:
# [<a class="text-grey-lightest" href="https://epaper.dawn.com">EPAPER</a>, <a class="text-grey-lightest" href="https://www.dawnnews.tv/watch-live">LIVE TV</a>, <a class="text-grey-lightest" href="https://www.dawnnews.tv">DAWNNEWS URDU</a>, <a class="text-grey-lightest" href="https://images.dawn.com">Images</a>, <a class="text-grey-lightest" href="https://herald.dawn.com">Herald</a>, <a class="text-grey-lightest" href="https://aurora.dawn.com">Aurora</a>, <a class="text-grey-lightest" href="https://cityfm89.com" rel="noreferrer" target="_blank">CityFM89</a>, <a class="text-grey-lightest" href="https://www.youtube.com/channel/UCkMdI0K-74jAjOmh5J5H97Q" rel="noreferrer" target="_blank">Teeli</a>, <a class="text-grey-lightest" href="https://www.dawn.com/advertise" rel="noreferrer" target="_blank">Advertise</a>, <a class="text-grey-lightest" href="https://educationexpo.dawn.com" rel="noreferrer" target="_blank">Events</a>, <a class="text-grey-lightest" href="https://www.dawn.com/events/supp
# ...

# %%
#print all the links which have pakistan in it and also the attirbute of that link. 
for link in links:
    if 'Pakistan' in link.text:
        print(link)
        print(link.attrs['href'])
        if 'Pakistan' in
# Out:
# <a class="" href="/pakistan">Pakistan</a>
# /pakistan
# <a class="text-3" href="/pakistan" title="Pakistan">Pakistan</a>
# /pakistan
# <a class="story__link" href="https://www.dawn.com/news/1574021/release-of-kaavan-the-elephant-reignites-zoo-debate-in-pakistan">Release of Kaavan the elephant reignites zoo debate in Pakistan
# </a>
# https://www.dawn.com/news/1574021/release-of-kaavan-the-elephant-reignites-zoo-debate-in-pakistan
# <a class="story__link" href="https://www.dawn.com/news/1574040/waqar-hopes-pakistan-can-cash-in-on-stokes-absence-in-second-test">Waqar hopes Pakistan can 'cash in' on Stokes' absence in second Test
# </a>
# https://www.dawn.com/news/1574040/waqar-hopes-pakistan-can-cash-in-on-stokes-absence-in-second-test
# <a class="story__link" href="https://www.dawn.com/news/1574041/north-macedonia-police-find-148-migrants-including-81-pakistanis-in-trucks">North Macedonia police find 148 migrants, including 81 Pakistanis, in trucks
# </a>
# ...

# %%
# Out:
#   File "<ipython-input-25-ad59485169df>", line 2
#     \
#      ^
# SyntaxError: unexpected EOF while parsing

# %%
# Out:
# ['https://epaper.dawn.com', 'https://www.dawn.com/news/1574044/hafeez-to-self-isolate-after-breaching-bio-security-protocol-in-england', 'https://www.dawn.com/news/1574021/release-of-kaavan-the-elephant-reignites-zoo-debate-in-pakistan', 'https://www.dawn.com/news/1574040/waqar-hopes-pakistan-can-cash-in-on-stokes-absence-in-second-test', 'https://www.dawn.com/news/1574041/north-macedonia-police-find-148-migrants-including-81-pakistanis-in-trucks', 'https://www.dawn.com/news/1574038/us-state-secretary-defends-saudi-arms-sales-after-watchdog-report', 'https://www.dawn.com/news/1574037/monsoon-floods-expose-blockages-in-karachis-drains-and-politics', 'https://www.dawn.com/news/1574034/indian-cyber-attack-targeting-gadgets-of-govt-officials-military-personnel-identified-ispr', 'https://www.dawn.com/news/1574031/women-journalists-demand-protection-from-vicious-social-media-attacks-by-people-linked-to-govt', 'https://www.dawn.com/news/1574030/stokes-absence-leaves-england-with-pakistan-pr
# ...

# %%
# Out:
# h
# https://www.dawn.com/news/1574021/release-of-kaavan-the-elephant-reignites-zoo-debate-in-pakistan

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-e8cb5cd8f224> in <module>
# ----> 1 import cv2
#       2 import pytesseract
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\92335\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
# Out:
#   File "<ipython-input-6-9a3f0412e7db>", line 1
#     $ tesseract --version
#     ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "<ipython-input-9-9a3f0412e7db>", line 1
#     $ tesseract --version
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# NEW UPDATE 15/11

# %%
r1 = requests.get(my_url)

# %%
coverpage = r1.content

# %%
import requests
from bs4 import BeautifulSoup

# %%
soup1 = BeautifulSoup(coverpage, 'html.parser')    
print(soup1)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>  <html lang="en" class="ie ie6 lte9 lte8 lte7"> <![endif]-->
# <!--[if IE 7]>     <html lang="en" class="ie ie7 lte9 lte8 lte7"> <![endif]-->
# <!--[if IE 8]>     <html lang="en" class="ie ie8 lte9 lte8"> <![endif]-->
# <!--[if IE 9]>     <html lang="en" class="ie ie9 lte9"> <![endif]-->
# <!--[if gt IE 9]>  <html lang="en"> <![endif]-->
# <!--[if !IE]><!--> <html lang="en"> <!--<![endif]-->
# <head>
# <!-- meta -->
# <meta charset="utf-8"/>
# <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
# <!--[if IE]> <meta http-equiv="X-UA-Compatible" content="IE=edge" /> <![endif]-->
# <title>News Archives for 2020-08-12 - DAWN.COM</title>
# <meta content="Your window to latest news, analysis and features from Pakistan, South Asia and the world." name="subject">
# <meta content="1383068068604634" property="fb:app_id">
# <meta content="86398345441" property="fb:pages"/>
# <meta content="en_US" property="og:locale"/>
# ...

# %%
coverpage_news = soup1.find_all('a', class_='story__link')
print(coverpage_news)
# Out:
# [<a class="story__link" href="https://www.dawn.com/news/1574044/hafeez-to-self-isolate-after-breaching-bio-security-protocol-in-england">Hafeez to self-isolate after breaching bio-security protocol in England
# </a>, <a class="story__link" href="https://www.dawn.com/news/1574021/release-of-kaavan-the-elephant-reignites-zoo-debate-in-pakistan">Release of Kaavan the elephant reignites zoo debate in Pakistan
# </a>, <a class="story__link" href="https://www.dawn.com/news/1574040/waqar-hopes-pakistan-can-cash-in-on-stokes-absence-in-second-test">Waqar hopes Pakistan can 'cash in' on Stokes' absence in second Test
# </a>, <a class="story__link" href="https://www.dawn.com/news/1574041/north-macedonia-police-find-148-migrants-including-81-pakistanis-in-trucks">North Macedonia police find 148 migrants, including 81 Pakistanis, in trucks
# ...

# %%
a = len(coverpage_news)
print(a)
print(coverpage_news[4].get_text())
news_contents = []
list_links = []
list_titles = []
for n in np.arange(0, a):
    # Getting the title
    #print(n)
    # Getting the title
    title = coverpage_news[n].get_text()
    list_titles.append(title)
print(list_titles)
# Out:
# 142
# US state secretary defends Saudi arms sales after watchdog report
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-2d735e7877f9> in <module>
#       9     # only news articles (there are also albums and other things)
#      10     # Getting the link of the article
# ---> 11         link = coverpage_news[n].find('a')['href']
#      12         list_links.append(link)
#      13         print(list_links)
#
# TypeError: 'NoneType' object is not subscriptable
