# %%
# !pip install --upgrade gupload
import sys
import pandas as pd
import urllib.request
import time
from urllib.request import HTTPError
from pydrive.auth import GoogleAuth
from google.colab import auth
auth.authenticate_user()
def download_file(download_url, filename):
  try:
    response = urllib.request.urlopen(download_url)
  except (http.client.IncompleteRead) as e:
    response = e.partial    
  file = open(filename + ".pdf", 'wb')
  file.write(response.read())
  file.close()
# Out:
# ...
#      |████████████████████████████████| 61kB 2.9MB/s
# ...
#      |████████████████████████████████| 81kB 3.2MB/s
# ...
# ERROR: earthengine-api 0.1.254 has requirement google-api-python-client>=1.12.1, but you'll have google-api-python-client 1.7.10 which is incompatible.
# ...
#   Found existing installation: google-api-python-client 1.12.8
#     Uninstalling google-api-python-client-1.12.8:
#       Successfully uninstalled google-api-python-client-1.12.8
#   Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ...

# %%
df = pd.read_csv('Input/data2019.csv')
df.head(4900)
#3558 #7500
# Out:
#               Date                                               Link
# 0     Jan 31, 2019  https://dps.psx.com.pk/download/document/12530...
# 1     Jan 31, 2019  https://dps.psx.com.pk/download/document/12530...
# 2     Jan 31, 2019  https://dps.psx.com.pk/download/document/12529...
# 3     Jan 31, 2019  https://dps.psx.com.pk/download/document/12529...
# 4     Jan 31, 2019  https://dps.psx.com.pk/download/document/12529...
# ...            ...                                                ...
# 4895  Jul 31, 2019  https://dps.psx.com.pk/download/document/13307...
# 4896  Jul 31, 2019  https://dps.psx.com.pk/download/document/13307...
# 4897  Jul 31, 2019  https://dps.psx.com.pk/download/document/13307...
# 4898  Jul 31, 2019  https://dps.psx.com.pk/download/document/13307...
# 4899  Jul 31, 2019  https://dps.psx.com.pk/download/document/13306...
#
# [4900 rows x 2 columns]

# %%
a='abcdefghijklmnopqrstuvwxyz!@#$%^&*()_+-=[]{}|:;,.<>?'
c=-1
for i in range(6445,7550):
  c+=1
  try:
    if c == len(a):
      c=-1
    if c != len(a):
      download_file(df['Link'][i], df['Date'][i]+a[c])
      print(i)
  except HTTPError:
    continue
# !zip -r /content/2019_filecomplete.zip /content
# !gupload --to '1eEEKhb3Yl_VrP30OwmVY2-CPoCf1rh6J' *.zip
# Out:
# 6445
# 6446
# 6447
# 6448
# 6449
# 6450
# 6451
# 6452
# 6453
# 6454
# 6455
# 6456
# 6457
# 6458
# 6459
# 6460
# 6461
# 6462
# 6463
# 6464
# 6465
# 6466
# 6467
# 6468
# 6469
# 6470
# 6471
# 6472
# 6473
# 6474
# 6475
# 6476
# 6477
# 6478
# 6479
# 6480
# 6481
# 6482
# 6483
# 6484
# 6485
# 6486
# 6487
# 6488
# 6489
# 6490
# 6491
# 6492
# 6493
# 6494
# 6495
# 6496
# 6497
# 6498
# 6499
# 6500
# 6501
# 6502
# 6503
# 6504
# 6505
# 6506
# 6507
# 6508
# 6509
# 6510
# 6511
# 6512
# 6513
# 6514
# 6515
# 6516
# 6517
# 6518
# 6519
# 6520
# 6521
# 6522
# 6523
# 6524
# 6525
# 6526
# 6527
# 6528
# 6529
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# <ipython-input-3-73d6eccac8e4> in <module>()
#       7       c=-1
#       8     if c != len(a):
# ----> 9       download_file(df['Link'][i], df['Date'][i]+a[c])
#      10       print(i)
#      11   except HTTPError:
#
# ...
