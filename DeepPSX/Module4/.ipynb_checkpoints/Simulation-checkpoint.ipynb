# %% [markdown]
# ### Module 4: BackTesting

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# ### Loading the Predicted Price

# %%
KSE100 = pd.read_csv('Input/KSE100.csv')
filtered = KSE100['Ticker'].tolist()

# %%
df1 = pd.DataFrame(columns = ['signal', 'price', 'total_shares', 'transaction', 'wallet'])
df2 = pd.DataFrame(columns = ['signal', 'wallet', 'profit'])
df3 = pd.DataFrame(columns = ['name','initial','final','percentage'])
profit_list = []

# %%
def model4(name,temp,money,percent):
    global df1
    global df2
    global df3
    global profit_list
    initial_money = money
    bought = False
    total_shares = 0
    df1.drop(df1.index, inplace=True)
    df2.drop(df2.index, inplace=True)
    df1 = df1.append({'price': 0, 'signal' : 0 , 'total_shares' : 0 , 'transaction' : 0, 'wallet': money }, ignore_index=True)
    df2 = df2.append({'signal' : 0 , 'wallet': money, 'profit' : initial_money - money}, ignore_index=True)

    for i in range(1,len(temp)):
        money_to_use = money * percent / 100
        if (temp['Pred'][i] == 1):
            if (money_to_use > temp['Close'][i]):
                num_shares = math.floor(money_to_use / temp['Close'][i])
                total_shares = total_shares + num_shares
                money = money - (num_shares * temp['Close'][i])
                bought_price = temp['Close'][i]
                bought = True
                df1 = df1.append({'price': temp['Close'][i], 'signal' : 1, 'total_shares' : total_shares, 'transaction': total_shares * temp['Close'][i], 'wallet' : money}, ignore_index=True)

        elif (temp['Pred'][i] == -1) and (bought == True):
            money = money + (total_shares * temp['Close'][i])
            df1 = df1.append({'price': temp['Close'][i], 'signal' : -1 , 'total_shares' : total_shares, 'transaction': total_shares * temp['Close'][i], 'wallet' : money}, ignore_index=True)
            df2 = df2.append({'signal' : -1 , 'wallet': money, 'profit' : money - initial_money}, ignore_index=True)
            bought = False
            total_shares = 0

        else:
            df1 = df1.append({'price': temp['Close'][i], 'signal' : temp['Pred'][i]  , 'total_shares' : total_shares, 'transaction': total_shares * temp['Close'][i], 'wallet' : money}, ignore_index=True)

    if bought == True:
        money = money + (total_shares * temp['Close'][i])
        total_shares = 0

    df1 = df1.append({'price': 0, 'signal' : 0 , 'total_shares' : 0, 'transaction': 0, 'wallet': money}, ignore_index=True)
    prof = float ((money - initial_money) / initial_money * 100) 

    print('Initial Wallet = ', initial_money)
    print('Percentage Profit = ', prof)
    print('Final Wallet = ', money)

    profit_list.append(prof)
    df3 = df3.append({'name': name, 'initial' : initial_money , 'final' : money, 'percentage': prof}, ignore_index=True)
    print('\n')
    
    if name == 'HBL PA Equity':
        plt.figure(figsize=(15, 5))
        plt.bar(df1.index, df1['wallet'], color ='maroon',
        width = 0.4)
        
        plt.show()
        plt.figure(figsize=(15, 5))
        plt.plot(df1.index,df1['wallet'])
        plt.title('Profit/Loss')
        plt.xlabel('Days')
        plt.ylabel('Wallet')
        plt.show()
        
        plt.figure(figsize=(15, 5))
        plt.plot(df2.index,df2['profit'])
        plt.title('Profit/Loss')
        plt.xlabel('Days')
        plt.ylabel('Profit')
        plt.show()

# %%
for name in filtered:
    fullName = 'Input/' + name + '.csv'
    file = pd.read_csv(fullName)
    print(name, ' Prediction on 50% Wallet')
    model4(name,file,100000,50)
# Out:
# HBL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  54.85824709999992
# Final Wallet =  154858.24709999992
# UBL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  47.91559350000002
# Final Wallet =  147915.59350000002
#
#
# HUBC PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  10.77032449999993
# Final Wallet =  110770.32449999993
#
#
# MCB PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  12.139671000000046
# Final Wallet =  112139.67100000005
#
#
# OGDC PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  13.031931100000046
# Final Wallet =  113031.93110000005
#
#
# LUCK PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  58.71171260000009
# Final Wallet =  158711.7126000001
#
#
# ENGRO PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  7.954689800000021
# Final Wallet =  107954.68980000002
#
#
# PPL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  26.820047500000044
# Final Wallet =  126820.04750000004
#
#
# FFC PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -8.028556800000107
# Final Wallet =  91971.44319999989
#
#
# PSO PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  17.05816219999995
# Final Wallet =  117058.16219999995
#
#
# DAWH PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  49.97365610000003
# Final Wallet =  149973.65610000002
#
#
# DGKC PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  104.85162749999995
# Final Wallet =  204851.62749999994
#
#
# POL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  22.793044599999906
# Final Wallet =  122793.0445999999
#
#
# EFERT PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  4.860691499999986
# Final Wallet =  104860.69149999999
#
#
# KAPCO PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  39.82755150000003
# Final Wallet =  139827.55150000003
#
#
# NBP PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  12.076909999999916
# Final Wallet =  112076.90999999992
#
#
# NESTLE PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -14.922880500000012
# Final Wallet =  85077.11949999999
#
#
# SEARL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  49.08133349999989
# Final Wallet =  149081.3334999999
#
#
# BAHL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  7.457311600000017
# Final Wallet =  107457.31160000002
#
#
# FCCL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  78.90001350000006
# Final Wallet =  178900.01350000006
#
#
# MLCF PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  212.21818770000013
# Final Wallet =  312218.1877000001
#
#
# KEL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -14.153190000000032
# Final Wallet =  85846.80999999997
#
#
# PSEL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -5.438950000000012
# Final Wallet =  94561.04999999999
#
#
# PIBTL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  7.122239999999932
# Final Wallet =  107122.23999999993
#
#
# PKGS PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  179.94472240000005
# Final Wallet =  279944.7224
#
#
# NML PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  35.90290560000003
# Final Wallet =  135902.90560000003
#
#
# BAFL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  11.93710049999987
# Final Wallet =  111937.10049999987
#
#
# MARI PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  26.69402709999989
# Final Wallet =  126694.02709999989
#
#
# PAEL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  86.07968
# Final Wallet =  186079.68
#
#
# FFBL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  62.05083800000008
# Final Wallet =  162050.83800000008
#
#
# KTML PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  71.59752429999993
# Final Wallet =  171597.52429999993
#
#
# ABOT PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -25.396007299999923
# Final Wallet =  74603.99270000008
#
#
# ABL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -0.6383979000000399
# Final Wallet =  99361.60209999996
#
#
# TRG PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  129.23156000000012
# Final Wallet =  229231.5600000001
#
#
# EFUG PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  18.016050700000022
# Final Wallet =  118016.05070000002
#
#
# FCEPL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  16.048920000000056
# Final Wallet =  116048.92000000006
#
#
# INDU PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  79.68052000000007
# Final Wallet =  179680.52000000008
#
#
# NRL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  69.28011000000002
# Final Wallet =  169280.11000000002
#
#
# MUREB PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -30.88973959999997
# Final Wallet =  69110.26040000003
#
#
# FATIMA PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  10.602831199999928
# Final Wallet =  110602.83119999993
#
#
# HCAR PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  150.9771575000001
# Final Wallet =  250977.1575000001
#
#
# NATF PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  77.70766690000013
# Final Wallet =  177707.66690000013
#
#
# HASCOL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  54.183840000000025
# Final Wallet =  154183.84000000003
#
#
# PIOC PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  339.1507399999998
# Final Wallet =  439150.7399999998
#
#
# HMB PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -6.01369809999998
# Final Wallet =  93986.30190000002
#
#
# PAKT PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -26.437121199999996
# Final Wallet =  73562.8788
#
#
# JDWS PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -21.186272800000065
# Final Wallet =  78813.72719999994
#
#
# CHCC PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  320.70980799999995
# Final Wallet =  420709.80799999996
#
#
# KOHC PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  109.72681479999984
# Final Wallet =  209726.81479999985
#
#
# AICL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  13.803870099999898
# Final Wallet =  113803.8700999999
#
#
# MTL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  73.79605460000003
# Final Wallet =  173796.05460000003
#
#
# GLAXO PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  67.95412200000001
# Final Wallet =  167954.122
#
#
# THALL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  62.9178428999999
# Final Wallet =  162917.8428999999
#
#
# ATRL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  95.98430999999991
# Final Wallet =  195984.3099999999
#
#
# PSMC PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  295.7871254
# Final Wallet =  395787.1254
#
#
# APL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  68.84559689999995
# Final Wallet =  168845.59689999995
#
#
# FEROZ PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  203.7032117
# Final Wallet =  303703.2117
#
#
# NCPL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  16.18465000000001
# Final Wallet =  116184.65000000001
#
#
# PTC PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  5.653640100000019
# Final Wallet =  105653.64010000002
#
#
# SNGP PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  26.187327300000092
# Final Wallet =  126187.32730000009
#
#
# ISL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  53.10614000000001
# Final Wallet =  153106.14
#
#
# NPL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  5.333255499999985
# Final Wallet =  105333.25549999998
#
#
# SSGC PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  30.874980000000097
# Final Wallet =  130874.9800000001
#
#
# IGIHL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  81.18851919999997
# Final Wallet =  181188.51919999998
#
#
# JLICL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  101.61696139999997
# Final Wallet =  201616.96139999997
#
#
# ICI PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  23.471637299999973
# Final Wallet =  123471.63729999997
#
#
# SHEL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  53.5612999999999
# Final Wallet =  153561.2999999999
#
#
# COLG PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  49.94328839999999
# Final Wallet =  149943.2884
#
#
# CPPL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  162.5717645
# Final Wallet =  262571.7645
#
#
# AKBL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  12.474935699999973
# Final Wallet =  112474.93569999997
#
#
# SHFA PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  38.772263999999964
# Final Wallet =  138772.26399999997
#
#
# BATA PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  1.6286062999999993
# Final Wallet =  101628.6063
#
#
# GHGL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  23.726045799999934
# Final Wallet =  123726.04579999993
#
#
# HGFA PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -17.902019999999947
# Final Wallet =  82097.98000000005
#
#
# SPWL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -4.9415553000000365
# Final Wallet =  95058.44469999996
#
#
# FABL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -7.789669999999969
# Final Wallet =  92210.33000000003
#
#
# SRVI PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  78.07084670000005
# Final Wallet =  178070.84670000005
#
#
# AHCL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  91.09354
# Final Wallet =  191093.54
#
#
# DCR PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -3.9808199000000024
# Final Wallet =  96019.1801
#
#
# BOP PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  5.296226900000038
# Final Wallet =  105296.22690000004
#
#
# PICT PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -1.4549304000000411
# Final Wallet =  98545.06959999996
#
#
# JSCL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  145.47073999999986
# Final Wallet =  245470.73999999987
#
#
# NCL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  23.843026899999796
# Final Wallet =  123843.0268999998
#
#
# MEBL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  39.7371219
# Final Wallet =  139737.1219
#
#
# HUMNL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  351.2922900000001
# Final Wallet =  451292.2900000001
#
#
# SNBL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -62.137321100000044
# Final Wallet =  37862.67889999996
#
#
# FML PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  43.906242600000056
# Final Wallet =  143906.24260000006
#
#
# SCBPL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -14.367955500000098
# Final Wallet =  85632.0444999999
#
#
# JGICL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -25.3800983000001
# Final Wallet =  74619.9016999999
#
#
# RMPL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -9.31641979999999
# Final Wallet =  90683.58020000001
#
#
# LPL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -15.476244000000005
# Final Wallet =  84523.756
#
#
# PKGP PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  4.972604699999996
# Final Wallet =  104972.6047
#
#
# EFUL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -13.862815799999998
# Final Wallet =  86137.1842
#
#
# OLPL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  4.5230386000000875
# Final Wallet =  104523.03860000009
#
#
# IDYM PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  16.28790559999991
# Final Wallet =  116287.90559999991
#
#
# ARM PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -15.254920000000013
# Final Wallet =  84745.07999999999
#
#
# IBFL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  -1.2900486999999994
# Final Wallet =  98709.9513
#
#
# PUNO PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  0.5870299999999988
# Final Wallet =  100587.03
#
#
# BNWM PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  4.945309999999998
# Final Wallet =  104945.31
#
#
# ASRL PA Equity  Prediction on 50% Wallet
# Initial Wallet =  100000
# Percentage Profit =  0.0
# Final Wallet =  100000

# %% [markdown]
# ### Calculating Profit/Loss

# %% [markdown]
# ### Investing on 50% of Wallet

# %% [markdown]
# ### List of Percentage Profits

# %%
df3.describe()
# Out:
#                final  percentage
# count     100.000000  100.000000
# mean   147207.995038   47.207995
# std     76810.825700   76.810826
# min     37862.678900  -62.137321
# 25%    101368.212225    1.368212
# 50%    123132.340950   23.132341
# 75%    168954.225175   68.954225
# max    451292.290000  351.292290

# %% [markdown]
# ### Average Percentage Profit

# %%
statistics.mean(profit_list)
# Out:
# 47.207995037999986
