# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
KSE100 = pd.read_csv('KSE100.csv')

# %%
KSE100.head()
# Out:
#            Ticker                          Name    Weight      Shares   Price
# 0   HBL PA Equity                Habib Bank Ltd  6.827582  660.083629  216.56
# 1   UBL PA Equity      United Bank Ltd/Pakistan  4.694459  489.671875  200.72
# 2  HUBC PA Equity          Hub Power Co Ltd/The  4.465812  752.150352  124.31
# 3   MCB PA Equity                  MCB Bank Ltd  4.447275  445.212299  209.14
# 4  OGDC PA Equity  Oil & Gas Development Co Ltd  4.313295  645.139260  139.98

# %%
new_data = pd.read_csv('closing11.csv', 
                  names=["Date", "Ticker", "x", "y","Open", "High","Low","Close","Volume"]
                  ,index_col=False)
new_data = new_data.drop(['x', 'y'], axis = 1)
new_data.head()
# Out:
#         Date Ticker   Open   High    Low  Close  Volume
# 0  20-Nov-20   HGFA   8.00   8.20   7.99   8.09   19000
# 1  20-Nov-20   HIFA   3.08   3.12   3.08   3.12    4500
# 2  20-Nov-20  SINDM   8.42   8.42   8.40   8.40    8000
# 3  20-Nov-20   TSMF   4.30   4.65   4.10   4.18    5500
# 4  20-Nov-20    BRR  11.42  11.48  11.41  11.48    2000

# %%
df = new_data.iloc[5:]
df.head()
# Out:
#         Date Ticker   Open   High    Low  Close  Volume
# 5  20-Nov-20   FECM   3.26   3.26   3.12   3.14    1500
# 6  20-Nov-20    FEM   2.70   2.70   2.60   2.61   21000
# 7  20-Nov-20   FFLM   3.25   3.25   3.25   3.25     500
# 8  20-Nov-20  ORIXM  17.69  17.70  17.69  17.70    1000
# 9  20-Nov-20   FHAM   9.77  10.10   9.75   9.90  140500

# %%
new_data.head(10)
# Out:
#         Date Ticker   Open   High    Low  Close  Volume
# 0  20-Nov-20   HGFA   8.00   8.20   7.99   8.09   19000
# 1  20-Nov-20   HIFA   3.08   3.12   3.08   3.12    4500
# 2  20-Nov-20  SINDM   8.42   8.42   8.40   8.40    8000
# 3  20-Nov-20   TSMF   4.30   4.65   4.10   4.18    5500
# 4  20-Nov-20    BRR  11.42  11.48  11.41  11.48    2000
# 5  20-Nov-20   FECM   3.26   3.26   3.12   3.14    1500
# 6  20-Nov-20    FEM   2.70   2.70   2.60   2.61   21000
# 7  20-Nov-20   FFLM   3.25   3.25   3.25   3.25     500
# 8  20-Nov-20  ORIXM  17.69  17.70  17.69  17.70    1000
# 9  20-Nov-20   FHAM   9.77  10.10   9.75   9.90  140500

# %%
filtered = KSE100['Ticker'].tolist() #Filtered companies stored in a list
new_data['Ticker'] = new_data['Ticker'].astype(str)
df = new_data[(new_data['Ticker']+' PA Equity').isin(filtered)]
name = []
for i in range(len(df)):
  name.append(df.iat[i,1] + ' PA Equity')
for i in range(len(df)):
  if name[i] in filtered: #Extracts only shortlisted companies
      df = new_data #Extract all rows under those 7 columns
      df['Open'] = pd.to_numeric(df['Open']) #Change datatype of Open (Initially object type)
      df['High'] = pd.to_numeric(df['High']) #Change datatype of High (Initially object type)
      df['Low'] = pd.to_numeric(df['Low']) #Change datatype of Low (Initially object type)
      df['Close'] = pd.to_numeric(df['Close']) #Change datatype of Close (Initially object type)
      df['Volume'] = pd.to_numeric(df['Volume']) #Change datatype of Volume (Initially object type)
      df['Date'] = pd.to_datetime(df['Date']) #Change data type to datetime (Iitially object type)
      df = df.drop(['Ticker'], axis = 1)
      df.iloc[i:i+1].to_csv(path_or_buf = '/content/' + name[i] + '.csv', encoding='utf-8',  sep = ',', index = False) #Save dataframe as CSV
# Out:
# ['HGFA PA Equity', 'OLPL PA Equity', 'JSCL PA Equity', 'ABL PA Equity', 'AKBL PA Equity', 'BAFL PA Equity', 'BAHL PA Equity', 'BOP PA Equity', 'FABL PA Equity', 'HBL PA Equity', 'MEBL PA Equity', 'NBP PA Equity', 'HMB PA Equity', 'MCB PA Equity', 'SNBL PA Equity', 'SCBPL PA Equity', 'UBL PA Equity', 'AICL PA Equity', 'JLICL PA Equity', 'EFUG PA Equity', 'EFUL PA Equity', 'IGIHL PA Equity', 'JGICL PA Equity', 'IDYM PA Equity', 'FML PA Equity', 'NCL PA Equity', 'KTML PA Equity', 'NML PA Equity', 'BNWM PA Equity', 'THALL PA Equity', 'FCEPL PA Equity', 'JDWS PA Equity', 'CHCC PA Equity', 'DGKC PA Equity', 'FCCL PA Equity', 'KOHC PA Equity', 'LUCK PA Equity', 'MLCF PA Equity', 'PIOC PA Equity', 'PAKT PA Equity', 'ATRL PA Equity', 'NRL PA Equity', 'HUBC PA Equity', 'KEL PA Equity', 'LPL PA Equity', 'KAPCO PA Equity', 'NCPL PA Equity', 'NPL PA Equity', 'PKGP PA Equity', 'SPWL PA Equity', 'APL PA Equity', 'PSO PA Equity', 'SHEL PA Equity', 'SSGC PA Equity', 'SNGP PA Equity', 'HASCOL PA Equity', 'MARI PA Equity', 'OGDC PA Equity', 'POL PA Equity', 'PPL PA Equity', 'ISL PA Equity', 'HCAR PA Equity', 'INDU PA Equity', 'MTL PA Equity', 'PSMC PA Equity', 'PAEL PA Equity', 'PIBTL PA Equity', 'PICT PA Equity', 'HUMNL PA Equity', 'PTC PA Equity', 'TRG PA Equity', 'DAWH PA Equity', 'ENGRO PA Equity', 'EFERT PA Equity', 'FFBL PA Equity', 'FFC PA Equity', 'ABOT PA Equity', 'FEROZ PA Equity', 'GLAXO PA Equity', 'SEARL PA Equity', 'FATIMA PA Equity', 'ICI PA Equity', 'CPPL PA Equity', 'PKGS PA Equity', 'BATA PA Equity', 'SRVI PA Equity', 'NESTLE PA Equity', 'NATF PA Equity', 'GHGL PA Equity', 'SHFA PA Equity', 'DCR PA Equity']

# %%
# !zip -r /content.zip /content
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2020.11.13/ (stored 0%)
#   adding: content/.config/logs/2020.11.13/17.33.45.553060.log (deflated 53%)
#   adding: content/.config/logs/2020.11.13/17.33.07.342211.log (deflated 54%)
#   adding: content/.config/logs/2020.11.13/17.33.22.211003.log (deflated 87%)
#   adding: content/.config/logs/2020.11.13/17.33.44.836274.log (deflated 55%)
#   adding: content/.config/logs/2020.11.13/17.32.45.071309.log (deflated 92%)
#   adding: content/.config/logs/2020.11.13/17.33.29.478721.log (deflated 53%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 22%)
#   adding: content/.config/.metricsUUID (stored 0%)
#   adding: content/ABOT PA Equity.csv (deflated 19%)
#   adding: content/PPL PA Equity.csv (deflated 4%)
#   adding: content/PAKT PA Equity.csv (deflated 6%)
#   adding: content/NCPL PA Equity.csv (deflated 6%)
#   adding: content/DAWH PA Equity.csv (deflated 15%)
#   adding: content/closing11.csv (deflated 62%)
#   adding: content/SPWL PA Equity.csv (deflated 7%)
#   adding: content/THALL PA Equity.csv (deflated 14%)
#   adding: content/JGICL PA Equity.csv (deflated 6%)
#   adding: content/ENGRO PA Equity.csv (deflated 3%)
#   adding: content/OGDC PA Equity.csv (deflated 10%)
#   adding: content/NBP PA Equity.csv (deflated 19%)
#   adding: content/CPPL PA Equity.csv (deflated 7%)
#   adding: content/BOP PA Equity.csv (deflated 19%)
#   adding: content/EFERT PA Equity.csv (deflated 10%)
#   adding: content/SSGC PA Equity.csv (deflated 14%)
#   adding: content/PSMC PA Equity.csv (deflated 4%)
#   adding: content/EFUG PA Equity.csv (deflated 14%)
#   adding: content/KSE100.csv (deflated 53%)
#   adding: content/IGIHL PA Equity.csv (deflated 7%)
#   adding: content/KAPCO PA Equity.csv (deflated 4%)
#   adding: content/MCB PA Equity.csv (deflated 14%)
#   adding: content/PIOC PA Equity.csv (deflated 6%)
#   adding: content/NPL PA Equity.csv (deflated 8%)
#   adding: content/PAEL PA Equity.csv (deflated 16%)
#   adding: content/MEBL PA Equity.csv (deflated 13%)
#   adding: content/HASCOL PA Equity.csv (deflated 7%)
#   adding: content/FML PA Equity.csv (deflated 6%)
#   adding: content/INDU PA Equity.csv (deflated 13%)
#   adding: content/NESTLE PA Equity.csv (deflated 11%)
#   adding: content/PKGP PA Equity.csv (deflated 5%)
#   adding: content/FABL PA Equity.csv (deflated 17%)
#   adding: content/JLICL PA Equity.csv (deflated 16%)
#   adding: content/JSCL PA Equity.csv (deflated 15%)
#   adding: content/APL PA Equity.csv (deflated 4%)
#   adding: content/EFUL PA Equity.csv (deflated 9%)
#   adding: content/NCL PA Equity.csv (deflated 5%)
#   adding: content/SNBL PA Equity.csv (deflated 12%)
#   adding: content/SHFA PA Equity.csv (deflated 4%)
#   adding: content/AICL PA Equity.csv (deflated 11%)
#   adding: content/TRG PA Equity.csv (deflated 16%)
#   adding: content/DCR PA Equity.csv (deflated 21%)
#   adding: content/PSO PA Equity.csv (deflated 10%)
#   adding: content/OLPL PA Equity.csv (deflated 13%)
#   adding: content/BNWM PA Equity.csv (deflated 6%)
#   adding: content/GHGL PA Equity.csv (deflated 7%)
#   adding: content/PTC PA Equity.csv (deflated 18%)
#   adding: content/FCEPL PA Equity.csv (deflated 4%)
#   adding: content/NML PA Equity.csv (deflated 3%)
#   adding: content/GLAXO PA Equity.csv (deflated 11%)
#   adding: content/ICI PA Equity.csv (deflated 6%)
#   adding: content/ATRL PA Equity.csv (deflated 13%)
#   adding: content/BAFL PA Equity.csv (deflated 10%)
#   adding: content/FFBL PA Equity.csv (deflated 15%)
#   adding: content/FATIMA PA Equity.csv (deflated 8%)
#   adding: content/HMB PA Equity.csv (deflated 14%)
#   adding: content/HUMNL PA Equity.csv (deflated 11%)
#   adding: content/KTML PA Equity.csv (deflated 11%)
#   adding: content/UBL PA Equity.csv (deflated 13%)
#   adding: content/AKBL PA Equity.csv (deflated 14%)
#   adding: content/PIBTL PA Equity.csv (deflated 18%)
#   adding: content/.ipynb_checkpoints/ (stored 0%)
#   adding: content/POL PA Equity.csv (deflated 1%)
#   adding: content/SCBPL PA Equity.csv (deflated 15%)
#   adding: content/MTL PA Equity.csv (deflated 11%)
#   adding: content/MLCF PA Equity.csv (deflated 16%)
#   adding: content/DGKC PA Equity.csv (deflated 4%)
#   adding: content/SEARL PA Equity.csv (deflated 6%)
#   adding: content/SNGP PA Equity.csv (deflated 7%)
#   adding: content/HCAR PA Equity.csv (deflated 21%)
#   adding: content/NRL PA Equity.csv (deflated 8%)
#   adding: content/HUBC PA Equity.csv (deflated 4%)
#   adding: content/SHEL PA Equity.csv (deflated 9%)
#   adding: content/FCCL PA Equity.csv (deflated 11%)
#   adding: content/SRVI PA Equity.csv (deflated 15%)
#   adding: content/LUCK PA Equity.csv (deflated 14%)
#   adding: content/FEROZ PA Equity.csv (deflated 6%)
#   adding: content/CHCC PA Equity.csv (deflated 6%)
#   adding: content/LPL PA Equity.csv (deflated 13%)
#   adding: content/ABL PA Equity.csv (deflated 6%)
#   adding: content/PICT PA Equity.csv (deflated 16%)
#   adding: content/NATF PA Equity.csv (deflated 10%)
#   adding: content/BAHL PA Equity.csv (deflated 9%)
#   adding: content/KEL PA Equity.csv (deflated 7%)
#   adding: content/BATA PA Equity.csv (deflated 18%)
#   adding: content/FFC PA Equity.csv (deflated 19%)
#   adding: content/ISL PA Equity.csv (deflated 6%)
#   adding: content/HGFA PA Equity.csv (deflated 4%)
#   adding: content/JDWS PA Equity.csv (deflated 12%)
#   adding: content/KOHC PA Equity.csv (deflated 7%)
#   adding: content/IDYM PA Equity.csv (deflated 14%)
#   adding: content/PKGS PA Equity.csv (deflated 24%)
#   adding: content/HBL PA Equity.csv (deflated 3%)
#   adding: content/MARI PA Equity.csv (deflated 4%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)

# %%
from google.colab import files
files.download("/content.zip")
